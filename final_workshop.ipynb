# %% [markdown]
# <a href="https://colab.research.google.com/github/drcruzm/cursoP/blob/master/final_workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introducción

# %%
segundos_dia = 24*60*60
segundos_dia
# Out:
# 86400

# %%
seg_semana = segundos_dia*7
seg_semana
# Out:
# 604800

# %%
import numpy as np
from matplotlib import pyplot as plt

y = 200 + np.random.randn(100)
x = [x for x in range(len(y))]

plt.plot(x, y, '-') ;

# %%
import numpy as np
np.mean(y)
# Out:
# 199.955149360985

# %%
np.median(y)
# Out:
# 199.94172185202058

# %%
plt.hist(y, bins = 20) ;

# %%
# cargamos los datos
from vega_datasets import data
import pandas as pd

cars = data.cars()
cars.head(2)
# Out:
#                         Name  Miles_per_Gallon  ...       Year  Origin
# 0  chevrolet chevelle malibu              18.0  ... 1970-01-01     USA
# 1          buick skylark 320              15.0  ... 1970-01-01     USA
#
# [2 rows x 9 columns]

# %%
car['price'].describe()
# Out:
# count     2499.000000
# mean     18767.671469
# std      12116.094936
# min          0.000000
# 25%      10200.000000
# 50%      16900.000000
# 75%      25555.500000
# max      84900.000000
# Name: price, dtype: float64

# %%
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()')
# Out:
# alt.Chart(...)

# %%
cars[cars['Miles_per_Gallon'] < 15]
# Out:
#                                  Name  Miles_per_Gallon  ...       Year  Origin
# 6                    chevrolet impala              14.0  ... 1970-01-01     USA
# 7                   plymouth fury iii              14.0  ... 1970-01-01     USA
# 8                    pontiac catalina              14.0  ... 1970-01-01     USA
# 16                 plymouth 'cuda 340              14.0  ... 1970-01-01     USA
# 19            buick estate wagon (sw)              14.0  ... 1970-01-01     USA
# 31                          ford f250              10.0  ... 1970-01-01     USA
# 32                          chevy c20              10.0  ... 1970-01-01     USA
# 33                         dodge d200              11.0  ... 1970-01-01     USA
# 34                           hi 1200d               9.0  ... 1970-01-01     USA
# 45                   chevrolet impala              14.0  ... 1971-01-01     USA
# 46          pontiac catalina brougham              14.0  ... 1971-01-01     USA
# 47                   ford galaxie 500              14.0  ... 1971-01-01     USA
# 48                  plymouth fury iii              14.0  ... 1971-01-01     USA
# 49                  dodge monaco (sw)              12.0  ... 1971-01-01     USA
# 50           ford country squire (sw)              13.0  ... 1971-01-01     USA
# 51                pontiac safari (sw)              13.0  ... 1971-01-01     USA
# 69                   chevrolet impala              13.0  ... 1972-01-01     USA
# 70                   pontiac catalina              14.0  ... 1972-01-01     USA
# 72                   ford galaxie 500              14.0  ... 1972-01-01     USA
# 74                    mercury marquis              11.0  ... 1972-01-01     USA
# 75               buick lesabre custom              13.0  ... 1972-01-01     USA
# 76         oldsmobile delta 88 royale              12.0  ... 1972-01-01     USA
# 77             chrysler newport royal              13.0  ... 1972-01-01     USA
# 80   chevrolet chevelle concours (sw)              13.0  ... 1972-01-01     USA
# 81              ford gran torino (sw)              13.0  ... 1972-01-01     USA
# 82     plymouth satellite custom (sw)              14.0  ... 1972-01-01     USA
# 92                  buick century 350              13.0  ... 1973-01-01     USA
# 93                        amc matador              14.0  ... 1973-01-01     USA
# 94                   chevrolet malibu              13.0  ... 1973-01-01     USA
# 95                   ford gran torino              14.0  ... 1973-01-01     USA
# 97           mercury marquis brougham              12.0  ... 1973-01-01     USA
# 98          chevrolet caprice classic              13.0  ... 1973-01-01     USA
# 99                           ford ltd              13.0  ... 1973-01-01     USA
# 100          plymouth fury gran sedan              14.0  ... 1973-01-01     USA
# 101      chrysler new yorker brougham              13.0  ... 1973-01-01     USA
# 102          buick electra 225 custom              12.0  ... 1973-01-01     USA
# 103           amc ambassador brougham              13.0  ... 1973-01-01     USA
# 110                  chevrolet impala              11.0  ... 1973-01-01     USA
# 111                      ford country              12.0  ... 1973-01-01     USA
# 112            plymouth custom suburb              13.0  ... 1973-01-01     USA
# 113          oldsmobile vista cruiser              12.0  ... 1973-01-01     USA
# 131                  oldsmobile omega              11.0  ... 1973-01-01     USA
# 144          buick century luxus (sw)              13.0  ... 1974-01-01     USA
# 145         dodge coronet custom (sw)              14.0  ... 1974-01-01     USA
# 146             ford gran torino (sw)              14.0  ... 1974-01-01     USA
# 147                  amc matador (sw)              14.0  ... 1974-01-01     USA
# 166                          ford ltd              14.0  ... 1975-01-01     USA
# 173                   ford mustang ii              13.0  ... 1975-01-01     USA
# 197                  ford gran torino              14.5  ... 1976-01-01     USA
# 215        plymouth volare premier v8              13.0  ... 1976-01-01     USA
# 220                         chevy c10              13.0  ... 1976-01-01     USA
# 221                         ford f108              13.0  ... 1976-01-01     USA
# 222                        dodge d100              13.0  ... 1976-01-01     USA
#
# [53 rows x 9 columns]

# %%
cars[cars['Miles_per_Gallon'] > 30]
# Out:
#                     Name  Miles_per_Gallon  ...       Year  Origin
# 60   toyota corolla 1200              31.0  ... 1971-01-01   Japan
# 61           datsun 1200              35.0  ... 1971-01-01   Japan
# 136          datsun b210              31.0  ... 1974-01-01   Japan
# 138  toyota corolla 1200              32.0  ... 1974-01-01   Japan
# 151        toyota corona              31.0  ... 1974-01-01   Japan
# ..                   ...               ...  ...        ...     ...
# 398     toyota celica gt              32.0  ... 1982-01-01   Japan
# 399    dodge charger 2.2              36.0  ... 1982-01-01     USA
# 402            vw pickup              44.0  ... 1982-01-01  Europe
# 403        dodge rampage              32.0  ... 1982-01-01     USA
# 405           chevy s-10              31.0  ... 1982-01-01     USA
#
# [85 rows x 9 columns]

# %%
cars['Name'].value_counts()
# Out:
# ford pinto                6
# amc matador               5
# ford maverick             5
# toyota corolla            5
# amc gremlin               4
#                          ..
# dodge aspen 6             1
# toyota corona liftback    1
# ford f250                 1
# dodge challenger se       1
# mercury capri v6          1
# Name: Name, Length: 311, dtype: int64

# %%
cars[cars['Origin'].isin(['USA'])]
# Out:
#                           Name  Miles_per_Gallon  ...       Year  Origin
# 0    chevrolet chevelle malibu              18.0  ... 1970-01-01     USA
# 1            buick skylark 320              15.0  ... 1970-01-01     USA
# 2           plymouth satellite              18.0  ... 1970-01-01     USA
# 3                amc rebel sst              16.0  ... 1970-01-01     USA
# 4                  ford torino              17.0  ... 1970-01-01     USA
# ..                         ...               ...  ...        ...     ...
# 400           chevrolet camaro              27.0  ... 1982-01-01     USA
# 401            ford mustang gl              27.0  ... 1982-01-01     USA
# 403              dodge rampage              32.0  ... 1982-01-01     USA
# 404                ford ranger              28.0  ... 1982-01-01     USA
# 405                 chevy s-10              31.0  ... 1982-01-01     USA
#
# [254 rows x 9 columns]

# %%
cars[cars['Origin'].isin(['Europe'])]
# Out:
#                              Name  Miles_per_Gallon  ...       Year  Origin
# 10           citroen ds-21 pallas               NaN  ... 1970-01-01  Europe
# 25   volkswagen 1131 deluxe sedan              26.0  ... 1970-01-01  Europe
# 26                    peugeot 504              25.0  ... 1970-01-01  Europe
# 27                    audi 100 ls              24.0  ... 1970-01-01  Europe
# 28                       saab 99e              25.0  ... 1970-01-01  Europe
# ..                            ...               ...  ...        ...     ...
# 366     peugeot 505s turbo diesel              28.1  ... 1982-01-01  Europe
# 367                     saab 900s               NaN  ... 1982-01-01  Europe
# 368                  volvo diesel              30.7  ... 1982-01-01  Europe
# 383           volkswagen rabbit l              36.0  ... 1982-01-01  Europe
# 402                     vw pickup              44.0  ... 1982-01-01  Europe
#
# [73 rows x 9 columns]

# %%
car = pd.read_csv('https://www.dropbox.com/s/j4zs2fhlq9hck2k/cars.csv?dl=1')
car.head(2)
# Out:
#    Unnamed: 0  price   brand  ...       state  country     condition
# 0           0   6300  toyota  ...  new jersey      usa  10 days left
# 1           1   2899    ford  ...   tennessee      usa   6 days left
#
# [2 rows x 13 columns]

# %%
car.head(3)
# Out:
#    Unnamed: 0  price   brand  ...       state  country     condition
# 0           0   6300  toyota  ...  new jersey      usa  10 days left
# 1           1   2899    ford  ...   tennessee      usa   6 days left
# 2           2   5350   dodge  ...     georgia      usa   2 days left
#
# [3 rows x 13 columns]

# %%
boxplot = car.boxplot(column=['price'], figsize=(8, 7));

# %%
car.head()
car['color'].value_counts()
# Out:
# white                                      707
# black                                      516
# gray                                       395
# silver                                     300
# red                                        192
# blue                                       151
# no_color                                    61
# green                                       24
# orange                                      20
# gold                                        19
# charcoal                                    18
# brown                                       15
# yellow                                       9
# magnetic metallic                            6
# shadow black                                 5
# color:                                       5
# beige                                        5
# oxford white                                 4
# ingot silver metallic                        4
# triple yellow tri-coat                       3
# super black                                  3
# billet silver metallic clearcoat             3
# white platinum tri-coat metallic             2
# cayenne red                                  2
# off-white                                    2
# bright white clearcoat                       2
# black clearcoat                              2
# ruby red metallic tinted clearcoat           2
# tuxedo black metallic                        2
# pearl white                                  1
# purple                                       1
# phantom black                                1
# toreador red                                 1
# light blue                                   1
# dark blue                                    1
# kona blue metallic                           1
# glacier white                                1
# burgundy                                     1
# maroon                                       1
# jazz blue pearlcoat                          1
# tan                                          1
# ruby red                                     1
# competition orange                           1
# ingot silver                                 1
# royal crimson metallic tinted clearcoat      1
# morningsky blue                              1
# guard                                        1
# lightning blue                               1
# turquoise                                    1
# Name: color, dtype: int64

# %%
plt.figure(figsize=(22,7));
car['color'].value_counts().plot(kind='bar');

# %%
plt.figure(figsize=(22,7));
car['brand'].value_counts().plot(kind='bar');

# %%
car['brand'].value_counts().plot(kind='barh', figsize=(8, 7));

# %%
import seaborn as sns

# %%
sns.set_style('whitegrid')
#sns.countplot(y='year', data=car);
#sns.countplot(y='year', hue='title_status' , data= car);
sns.countplot(y='state', data=car);
sns.countplot(y='brand', hue='title_status', data=car);

# %%
# sns.histplot(car['price'], color='darkred',bins=60);
sns.histplot(car['price'], palette= 'Set3', bins=40);

# %%
plt.figure(figsize=(22,7));
sns.boxplot(x='brand', y='price',palette='winter',data=car);

# %%
sns.boxplot(x='state', y='price', palette='winter', data=car);

# %%
sns.kdeplot(car['year'],shade=True);

# %%
sns.kdeplot(car['price'], shade=True);

# %%
car['price'].describe()
# Out:
# count     2499.000000
# mean     18767.671469
# std      12116.094936
# min          0.000000
# 25%      10200.000000
# 50%      16900.000000
# 75%      25555.500000
# max      84900.000000
# Name: price, dtype: float64

# %%
car['price'].hist(bins=15);

# %%
cond = max(car['price'])
car['brand'] [car['price'] == cond]
# Out:
# 502    mercedes-benz
# Name: brand, dtype: object

# %%
car.head(1)
# Out:
#    Unnamed: 0  price   brand  ...       state  country     condition
# 0           0   6300  toyota  ...  new jersey      usa  10 days left
#
# [1 rows x 13 columns]

# %%
price = car.groupby('brand')['mileage'].min().reset_index()
price
# Out:
#               brand   mileage
# 0             acura   63500.0
# 1              audi   47213.0
# 2               bmw    7509.0
# 3             buick   12406.0
# 4          cadillac   16013.0
# 5         chevrolet       0.0
# 6          chrysler    2473.0
# 7             dodge    1091.0
# 8              ford       0.0
# 9               gmc       0.0
# 10  harley-davidson    9502.0
# 11        heartland       1.0
# 12            honda   16702.0
# 13          hyundai   25847.0
# 14         infiniti   11047.0
# 15           jaguar   20849.0
# 16             jeep    8395.0
# 17              kia   11451.0
# 18             land   20103.0
# 19            lexus    8186.0
# 20          lincoln   14541.0
# 21         maserati   37021.0
# 22            mazda   47753.0
# 23    mercedes-benz   19427.0
# 24           nissan       1.0
# 25        peterbilt       0.0
# 26              ram   30421.0
# 27           toyota  274117.0

# %%
price_new = price.set_index('brand')
price_new
price_new.plot(kind='pie', y='mileage', figsize=(15, 20));

# %%
price_new
# Out:
#                   mileage
# brand
# acura             63500.0
# audi              47213.0
# bmw                7509.0
# buick             12406.0
# cadillac          16013.0
# chevrolet             0.0
# chrysler           2473.0
# dodge              1091.0
# ford                  0.0
# gmc                   0.0
# harley-davidson    9502.0
# heartland             1.0
# honda             16702.0
# hyundai           25847.0
# infiniti          11047.0
# jaguar            20849.0
# jeep               8395.0
# kia               11451.0
# land              20103.0
# lexus              8186.0
# lincoln           14541.0
# maserati          37021.0
# mazda             47753.0
# mercedes-benz     19427.0
# nissan                1.0
# peterbilt             0.0
# ram               30421.0
# toyota           274117.0

# %%
price_new2 = price_new.drop(['toyota'])
price_new2.plot(kind='pie', y='mileage', figsize=(15, 20));

# %%
price = car.groupby('brand')['year'].max().reset_index()
price
# Out:
#               brand  year
# 0             acura  2014
# 1              audi  2017
# 2               bmw  2020
# 3             buick  2019
# 4          cadillac  2019
# 5         chevrolet  2020
# 6          chrysler  2020
# 7             dodge  2020
# 8              ford  2020
# 9               gmc  2019
# 10  harley-davidson  2016
# 11        heartland  2018
# 12            honda  2017
# 13          hyundai  2019
# 14         infiniti  2019
# 15           jaguar  2019
# 16             jeep  2019
# 17              kia  2020
# 18             land  2018
# 19            lexus  2020
# 20          lincoln  2019
# 21         maserati  2017
# 22            mazda  2016
# 23    mercedes-benz  2019
# 24           nissan  2020
# 25        peterbilt  2012
# 26              ram  2017
# 27           toyota  2008

# %%
price = car.groupby('brand')['price'].max().reset_index()
price
# Out:
#               brand  price
# 0             acura  16900
# 1              audi  36400
# 2               bmw  61200
# 3             buick  37500
# 4          cadillac  47500
# 5         chevrolet  63200
# 6          chrysler  29100
# 7             dodge  67000
# 8              ford  74000
# 9               gmc  48500
# 10  harley-davidson  54680
# 11        heartland   6680
# 12            honda  17200
# 13          hyundai   9800
# 14         infiniti  18500
# 15           jaguar   2800
# 16             jeep  21100
# 17              kia  21500
# 18             land  46900
# 19            lexus  55600
# 20          lincoln  36300
# 21         maserati  30300
# 22            mazda  16000
# 23    mercedes-benz  84900
# 24           nissan  36300
# 25        peterbilt   1025
# 26              ram  11050
# 27           toyota   6300

# %%
price.plot(kind='pie', y='price', figsize=(10, 10));

# %%
price_new = price.set_index('brand')
price_new
price_new.plot(kind='pie', y='price', figsize=(15, 20));
